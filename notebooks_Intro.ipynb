# %%
print(55/0)#zero division error, a number cannot be divided by zero.
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(55/0)
#
# ZeroDivisionError: division by zero

# %%
a=[]#indexerror:list index out of range.
print(a[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 a=[]
# ----> 2 print(a[5])
#
# IndexError: list index out of range

# %%
tup=(2,3,4,5,6)
tup[2]=0#type error as tup doesnot support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 tup=(2,3,4,5,6)
# ----> 2 tup[2]=0
#
# TypeError: 'tuple' object does not support item assignment

# %%
try:
    ticket=int(input("Enter the number of tickets you want"))
    print("Total cost",ticket*150)
except ValueError:
    print("please enter valid number of tickets")
# Out:
# Enter the number of tickets you want 12
# Total cost 1800

# %% [raw]
# filename=input("enter a filename")
# try:
#     f=open(filename,"r")
# except FileNotFoundError:
#     print("the above mentioned file doesnot exist.")

# %%
user_input=input("enter a number")
try:
    num=float(user_input)
except ValueError:
    print("You have not entered a number")
else:
    print("Square",num**2)
finally:
    print("Thankyou")
# Out:
# enter a number w
# You have not entered a number
# Thankyou

# %%
filename=input("enter filename")
try:
    with open(filename,"r") as infile:
        content=infile.read()
except FileNotFoundError:
    print("the file you have entered doesn't exist.")
except PermissionError:
    print("You don't have the permission to read this file")
# Out:
# enter filename ayush..txt
# the file you have entered doesn't exist.

# %%
def get_age():
    age=int(input("Enter your age"))
    if age < 0:
        raise ValueError(f"{age} is not a valud age")
    return age

# %%
def get_age():
    age=int(input("Enter your age"))
    if age < 0 or age >100:
        raise ValueError(f"{age} is not a valid age")
    return age
user_age=get_age()
print("The age is",user_age)
# Out:
# Enter your age 230
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       4         raise ValueError(f"{age} is not a valid age")
#       5     return age
# ----> 6 user_age=get_age()
#       7 print("The age is",user_age)
#
# Cell In[4], line 4, in get_age()
#       2 age=int(input("Enter your age"))
#       3 if age < 0 or age >100:
# ----> 4     raise ValueError(f"{age} is not a valid age")
#       5 return age
#
# ValueError: 230 is not a valid age
